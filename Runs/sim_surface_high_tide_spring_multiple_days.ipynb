# %% [markdown]
# # Simulation: only surface velocities, four days, high tide, spring

# %% [markdown]
# # Importing packages

# %%
import xarray as xr
import numpy as np
from datetime import timedelta
from parcels import FieldSet, ParticleSet, AdvectionRK4, JITParticle, plotTrajectoriesFile
import sys
sys.path.append("..")
import format_data
import matplotlib.pyplot as plt
import matplotlib as mpl
import cartopy.crs as ccrs
import cartopy.feature as cf
# Out:
# INFO: Compiled ParcelsRandom ==> /tmp/parcels-1000/libparcels_random_b4c23119-f2b8-41e2-a393-6e32a6dbbc1a.so

# %%
plt.style.use('seaborn-dark-palette')
plt.rcParams.update({'font.size': 18, 'figure.figsize': (12.8, 9.6)})
cmap = mpl.cm.get_cmap('viridis')

# %%
save_plots = True

# %% [markdown]
# # Empty map

# %%
def get_map():
    ax = plt.axes(projection=ccrs.PlateCarree())
    fig = plt.gcf()
    ax.set_extent([3.8,4.65,51.9,52.65])
    ax.coastlines()
    ax.add_feature(cf.BORDERS)
    ax.add_feature(cf.LAND)
    ax.add_feature(cf.OCEAN)
    ax.add_feature(cf.RIVERS)
    ax.gridlines(draw_labels=True)

    return fig, ax

# %% [markdown]
# # Preprocessing data

# %%
data_dir = format_data.data_dir("../../Data")
uxg = data_dir.preprocess("uxg")
uyg = data_dir.preprocess("uyg")

# %%
surface_uxg = uxg.__xarray_dataarray_variable__[:,19,:,:]
surface_uyg = uyg.__xarray_dataarray_variable__[:,19,:,:]

# %% [markdown]
# **Masking velocities on land**

# %%
surface_uxg_clipped = data_dir.clip(surface_uxg)
surface_uyg_clipped = data_dir.clip(surface_uyg)

# %%
surface_ds = xr.Dataset({"U": surface_uxg_clipped, "V": surface_uyg_clipped})

# %% [markdown]
# # Initializing the field for Parcels

# %%
variables = {"U": "U", "V": "V"}
dimensions = {"U": {"lat": "lat", "lon": "lon", "time": "time"},
              "V": {"lat": "lat", "lon": "lon", "time": "time"}}

fieldset = FieldSet.from_xarray_dataset(ds=surface_ds, variables=variables, dimensions=dimensions)
# Out:
# WARNING: Casting lon data to np.float32
# WARNING: Casting lat data to np.float32
# WARNING: Casting depth data to np.float32
# WARNING: Casting field data to np.float32

# %% [markdown]
# # Number, locations and timesteps of particles

# %%
npart = 7 # 7 particles
lon = 4.075 * np.ones(npart) 
lat = 51.995 * np.ones(npart)
time = (np.arange(0, npart) * timedelta(minutes=30).total_seconds()) + timedelta(days=8, hours=2, minutes=10).total_seconds() # Drop particles at 20 minute interval after 09:00 at 17-09
output_dt = timedelta(minutes=5)

# %% [markdown]
# # Particle set

# %%
pset = ParticleSet(fieldset=fieldset,
                   pclass=JITParticle,
                   lon=lon,
                   lat=lat,
                   time=time)

# %%
output_file = pset.ParticleFile(name="surface_high_tide_spring_four_days_output.nc",
                                    outputdt=output_dt)

# %% [markdown]
# # Execute kernel

# %%
pset.execute(AdvectionRK4,
             runtime=timedelta(days=4),
             dt=output_dt,
             output_file=output_file)
# Out:
# INFO: Compiled JITParticleAdvectionRK4 ==> /tmp/parcels-1000/83e114963bf86fcbd09834f8ee82a9d2_0.so
# INFO: Temporary output files are stored in out-VVPYSWMY.
# INFO: You can use "parcels_convert_npydir_to_netcdf out-VVPYSWMY" to convert these to a NetCDF file during the run.
# 100% (345600.0 of 345600.0) |############| Elapsed Time: 0:00:03 Time:  0:00:03

# %%
output_file.export()
output_file.close()

# %% [markdown]
# # Loading the output file

# %%
output = xr.open_dataset("surface_high_tide_spring_four_days_output.nc")

# %% [markdown]
# # Plotting

# %%
x = output['lon'].values
y = output['lat'].values

# %%
fig, ax = get_map()
for i in range(len(x)):
    ax.scatter(x[i], y[i], label=output.time[i,0].dt.strftime("%H:%M").values, s=0.4, color=cmap(0.2*i))
ax.legend(loc="upper left", markerscale=15, title="Time of release")
ax.set_title(f'Release after high tide, during spring tide ({output.time[0,0].dt.strftime("%d-%m-%y").values}) \n Runtime: 4 days')

if save_plots:
    plt.gcf().savefig("../figs/sim_surface_high_tide_spring_four_days.pdf", bbox_inches="tight")
